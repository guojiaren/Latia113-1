# %% [markdown]
# <a href="https://colab.research.google.com/github/guojiaren/Latia113-1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url = 'https://www.msn.com/zh-tw/news/living/%E5%86%B7%E6%B0%A3%E5%8A%A0%E5%83%B9-%E5%8D%87%E7%B4%9A1%E5%8A%9F%E8%83%BD-%E5%BE%88%E8%AE%9A-%E9%81%8E%E4%BE%86%E4%BA%BA%E6%BF%80%E6%8E%A8-%E4%B8%8D%E8%B2%B7%E6%9C%83%E5%BE%8C%E6%82%94/ar-AA1sZiw9?ocid=msedgntp&pc=U531&cvid=d0cde1e9a22f4c10b400a1ae6a825aa3&ei=12'
# 假的 headers 資訊
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36(KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
# 加入 headers 資訊
web = requests.get(url, headers=headers)
web.encoding = 'utf8'
print(web.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-us" dir="ltr" >
# ...

# %% [markdown]
# 處理亂碼文題

# %%
import requests
url = 'https://www.msn.com/zh-tw/news/living/%E5%86%B7%E6%B0%A3%E5%8A%A0%E5%83%B9-%E5%8D%87%E7%B4%9A1%E5%8A%9F%E8%83%BD-%E5%BE%88%E8%AE%9A-%E9%81%8E%E4%BE%86%E4%BA%BA%E6%BF%80%E6%8E%A8-%E4%B8%8D%E8%B2%B7%E6%9C%83%E5%BE%8C%E6%82%94/ar-AA1sZiw9?ocid=msedgntp&pc=U531&cvid=d0cde1e9a22f4c10b400a1ae6a825aa3&ei=12'
# 假的 headers 資訊
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36(KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
# 加入 headers 資訊
#web = requests.get(url, headers=headers)
#web.encoding = 'utf8'
print(web.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-us" dir="ltr" >
# ...

# %%
import requests
import json
import pandas as pd

# Fetch the JSON data
web = requests.get('https://data.kcg.gov.tw/dataset/6f29f6f4-2549-4473-aa90-bf60d10895dc/resource/30dfc2cf-17b5-4a40-8bb7-c511ea166bd3/download/lightrailtraffic.json')
data = json.loads(web.content.decode('utf-8-sig'))

# Convert JSON to DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
display(df)

# Save to Excel
df.to_excel('lightrailtraffic.xlsx', index=False)
print('Data saved to lightrailtraffic.xlsx')
# Out:
#       年   月      總運量   日均運量  假日均運量 月台上刷卡日均筆數 車上刷卡日均筆數  售票機日均筆數  補票日均筆數  \
# 0   107   1   275360   8883  15132    1734.2   5495.9   1516.8     9.4
# 1   107   2   413815  14779  20738    3854.9   9039.8   1754.9    11.9
# 2   107   3   209783   6767  13198    1413.2   4487.5    660.7     6.5
# 3   107   4   283651   9455  16656    2183.7   6013.8    944.5     6.3
# 4   107   5   206325   6656  11573    1385.8   4331.5    558.6     7.1
# ..  ...  ..      ...    ...    ...       ...      ...      ...     ...
# 77  113   6   936946  31232  37612   27698.4        0    873.1     NaN
# 78  113   7   904543  30151  38032   26764.8        0    956.2     NaN
# 79  113   8  1008981  32548  40730   28790.2        0   1088.3     NaN
# 80  113   9   928172  30939  34988     26822        0    731.3     NaN
# 81  113  10   886643  30574  39604   26568.2        0    734.6     NaN
#
#     團體票日均筆數  人工售票日均筆數                              備註 QR-CODE日均筆數
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://water.taiwanstat.com/'
web = requests.get(url)
# soup = BeautifulSoup(web.text, "html.parser") # 使用html.parser 解析器
soup = BeautifulSoup(web.text, "html5lib") # 使用 html5lib解析器
title = soup.title
print(title)
# Out:
# <title>台灣水庫即時水情</title>

# %%
from bs4 import BeautifulSoup
import requests as rq
#we need to request a web site
url = 'https://water.taiwanstat.com/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'}

response = rq.get(url, headers = headers, timeout=2)
html = response.content
#print(html)
soup = BeautifulSoup(html, "html.parser") # create a new bs4 object from the html data loaded
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "html.parser") # create a new bs4 object from the html data loaded
for script in soup(["script", "style"]): # remove all javascript and stylesheet code
    script.extract()
  # get text
    text = soup.get_text()
  # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
  # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split(" "))
  # drop blank lines
    texts = '\n'.join(chunk for chunk in chunks if chunk)
print(texts)
# Out:
# 蔣卓嘉冒「出血性瘜肉」緊急開刀　親揭術後好消息：下週開工│TVBS新聞網
# 首頁
# 娛樂
# 廣告
# "
# "
# 點擊關閉或任一空白處，繼續閱讀新聞。追蹤我們掌握最新動態訂閱電子報人氣點閱榜1小雪「九頭蛇兇星」發威！台灣將出大事　命理師斷言：災禍擋不住2婚宴菜全素沒先說！親友餓到叫20份大披薩　外國新娘當場痛哭3涉霸凌下屬致死　謝宜容靠山曝光！陳情全遭他擋下4辦公室超常見！英藥劑師點名3款「保健食品」：我絕對不會吃5職場霸凌害死公務員？勞動部頻惹議　賴清德致歉：深切檢討6馬路上跳格子？斑馬線旁突冒出「黃色方格」　內行示警：6千直接掰今日頭條中華隊遭委內瑞拉完封　曾豪駒認1失誤：教練擔失敗17分鐘前謝宜容親戚是雲林虎尾醬油世家　業者低調證實1小時前謝宜容聲明「提油救火」　她質疑：背後什麼來頭？47分鐘前
# 0
# 新聞
# 即時熱門社會娛樂政治國際生活健康理財房地產Focus食尚新奇科技體育大陸氣象Taiwan
# News汽車ESG永續
# 精選
# Live不漏接議題民調生態文明TVBS專欄樂透彩券對獎
# 專題
# 川普新內閣12強棒球賽政府部門霸凌優惠好康情報
# 大家都在搜尋
# 搜尋
# 訂閱電子報快速掌握一週精華
# 立即訂閱
# 您即將進入之新聞內容需滿18歲才可瀏覽
# 未滿18歲
# 已滿18歲
# 臺北市
# º
# -
# º
# 首頁12強棒球賽政府部門霸凌即時生活政治娛樂ESG永續氣象國際社會體育更多Taiwan
# News健康理財房地產TVBS專欄大陸Live不漏接汽車科技Focus食尚新奇議題民調生態文明
# 首頁12強棒球賽政府部門霸凌即時生活政治娛樂ESG永續氣象國際更多社會健康體育Taiwan
# News理財房地產TVBS專欄大陸Live不漏接汽車科技Focus食尚新奇議題民調生態文明
# 首頁12強棒球賽政府部門霸凌即時生活政治娛樂ESG永續氣象國際社會健康體育Taiwan
# News理財房地產熱門TVBS專欄大陸Live不漏接汽車科技Focus食尚新奇議題民調生態文明
# 分享至：
# 好康
# 即時新聞快報！　立即下載TVBS新聞APP
# 快訊
# 苗可麗錄影爆衝突！突「飆罵曾國城」全場嚇傻　下秒跪地全說了
# 快訊
# 中壢遊民誤會自己被拍！持安全帽攻擊　反被噴辣椒水痛蹲在地
# 快訊
# ...

# %%
import requests
web = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html')
print(web.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# <script>
# (() => {
#     if (document.cookie.indexOf('over18=1') === -1) {
# 	location = 'https://www.ptt.cc/ask/over18?from=' + encodeURIComponent(location.pathname);
#     }
# })();
# </script>
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# ...

# %%
web =requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',
cookies={'over18':'1'})

# %%
import requests
from bs4 import BeautifulSoup
import urllib.parse  # Import urllib.parse

url = 'https://www.ptt.cc/'
web = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', cookies={'over18': '1'})
soup = BeautifulSoup(web.text, "html.parser")
titles = soup.find_all('div', class_='title')

for i in titles:
    if i.find('a') is not None:  # Check if 'a' tag is found
        print(i.find('a').get_text())
        # Construct the complete URL using urllib.parse.urljoin
        complete_url = urllib.parse.urljoin(url, i.find('a')['href'])
        print(complete_url, end='\n\n')
# Out:
# Re: [爆卦] 俄羅斯向烏克蘭發射洲際彈道飛彈（ICBM）
# https://www.ptt.cc/bbs/Gossiping/M.1732178993.A.28A.html
#
# [問卦] 政府是不是維持最基本功能就好
# https://www.ptt.cc/bbs/Gossiping/M.1732179008.A.E96.html
#
# [問卦] 洲際彈道飛彈 飛到太空中 還需要警報嗎?
# https://www.ptt.cc/bbs/Gossiping/M.1732179062.A.6D9.html
#
# [問卦] 內雙的人是不是有時候會變外雙
# https://www.ptt.cc/bbs/Gossiping/M.1732179084.A.B21.html
#
# Re: [問卦] 數發部弄這衝三小？
# https://www.ptt.cc/bbs/Gossiping/M.1732179103.A.65B.html
#
# [問卦] 台積一堆謝等級的主管真的假的？
# https://www.ptt.cc/bbs/Gossiping/M.1732179161.A.D72.html
#
# 謝遺容的年薪
# https://www.ptt.cc/bbs/Gossiping/M.1732179329.A.37D.html
#
# [問卦] 文組想問 AI伺服器 跟楓之谷伺服器一樣嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1732179355.A.E74.html
#
# [問卦] 如果用海參崴換基輔 值得嗎
# https://www.ptt.cc/bbs/Gossiping/M.1732179400.A.CCD.html
#
# [問卦] 謝宜容跟虐死凱凱保母 長相有像嗎
# https://www.ptt.cc/bbs/Gossiping/M.1732179430.A.A44.html
#
# [問卦] 烏克蘭會被種香菇嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1732179447.A.4A8.html
#
# [問卦] 現實中  你敢惹宜容嗎？  就問一句
# ...

# %%
import requests
from bs4 import BeautifulSoup

web = requests.get('https://www.ptt.cc/bbs/Beauty/M.1710593264.A.578.html', cookies={'over18': '1'})
soup = BeautifulSoup(web.text, "html.parser")
imgs = soup.find_all('img')

for i in imgs:
    if 'src' in i.attrs:  # Check if 'src' attribute exists
        print(i['src'])
# Out:
# https://cache.ptt.cc/c/https/i.imgur.com/zSCKh5fl.jpg?e=1732369864&s=KmjRfK3B_arIFjHokcja1g
# https://cache.ptt.cc/c/https/i.imgur.com/4Xfq2nrl.jpg?e=1732374541&s=EIcX0hS46H0kjswqWvnVcg
# https://cache.ptt.cc/c/https/i.imgur.com/vJIMY03l.jpg?e=1732318836&s=HgNLPDkK1jgoN5umrFwkEw
# https://cache.ptt.cc/c/https/i.imgur.com/wKWzZBfl.jpg?e=1732317043&s=GXppg4TaL4-TvNtsXQInSg
# https://cache.ptt.cc/c/https/i.imgur.com/5a24s64l.jpg?e=1732332807&s=-lS9175ldxcWjB2Wtkx5Bg
# https://cache.ptt.cc/c/https/i.imgur.com/3bPuFPyl.jpg?e=1732357271&s=jiFDOjw3ZgyfYvwo7kiPBw
# https://cache.ptt.cc/c/https/i.imgur.com/FfVPpXyl.jpg?e=1732331817&s=WQQv0A8Gp-a6pCdQzZ5eSQ
# https://cache.ptt.cc/c/https/i.imgur.com/jGCMjBil.jpg?e=1732371362&s=NkRn4o0108IJam7KfyK_lg
# https://cache.ptt.cc/c/https/i.imgur.com/jDLMlT9l.jpg?e=1732358656&s=_Sj8dIWJ7hM__skUklJqhQ
# https://cache.ptt.cc/c/https/i.imgur.com/ACsDTnel.jpg?e=1732367376&s=0av-xekOQjj5I_o136sZMQ
# ...

# %%
import requests
from bs4 import BeautifulSoup

web = requests.get('https://www.ptt.cc/bbs/Beauty/M.1732158962.A.BE5.html', cookies={'over18': '1'})
soup = BeautifulSoup(web.text, "html.parser")
imgs = soup.find_all('img')

for i in imgs:
    if 'src' in i.attrs:  # Check if 'src' attribute exists
        print(i['src'])
# Out:
# https://cache.ptt.cc/c/https/i.imgur.com/ggg6gyll.jpeg?e=1732353934&s=G6iUIoHNg_zWS4UUiaMt9g
# https://cache.ptt.cc/c/https/i.imgur.com/hymliOEl.jpeg?e=1732313506&s=v24bggIPv4b_0UiZE4wSzQ
# https://cache.ptt.cc/c/https/i.imgur.com/cx01fq4l.jpeg?e=1732329736&s=aav00WxO-Mcexn0os9ybMA
# https://cache.ptt.cc/c/https/i.imgur.com/02BuJo8l.jpeg?e=1732359257&s=BeyFJO0nOYLQnGWfnxukVA
# https://cache.ptt.cc/c/https/i.imgur.com/rus3rKUl.jpeg?e=1732340504&s=LZMIiz6b_UZA-Pkmqj_Xgw
# https://cache.ptt.cc/c/https/i.imgur.com/Mi27HMUl.jpeg?e=1732321210&s=l_NFXv3calUW0smW-KtuwA
# https://cache.ptt.cc/c/https/i.imgur.com/rQH9DFLl.jpeg?e=1732344825&s=l23mdi4O3w6RNo-sTaiI8A
# https://cache.ptt.cc/c/https/i.imgur.com/Td5kuORl.jpeg?e=1732330599&s=FYeFha1zsS-Fq7yE-MKLEQ
# https://cache.ptt.cc/c/https/i.imgur.com/wV2d84rl.jpeg?e=1732348664&s=2HfWqf0OlvQEFsxyhLZPow
# https://cache.ptt.cc/c/https/i.imgur.com/cnVGVmRl.jpeg?e=1732362764&s=BL6BP17rG0RhzJAngd_r9g

# %%
import requests
from bs4 import BeautifulSoup
import os
from google.colab import drive
# 挂载 Google Drive(可选,如果需要保存到云端硬盘)
drive.mount('/content/drive')
# 定义并创建保存图片的目录
save_dir = '/content/drive/MyDrive/ Notebooks/download/'
if not os.path.exists(save_dir):os.makedirs(save_dir)
web = requests.get('https://www.ptt.cc/bbs/Beauty/M.1732158962.A.BE5.html',
cookies={'over18':'1'})
soup = BeautifulSoup(web.text, "html.parser")
imgs = soup.find_all('img')
name = 0 # 设定图片编号
for i in imgs:print(i['src'])
jpg = requests.get(i['src']) # 使用 requests 获取图片内容
with open(f'{save_dir}test_{name}.jpg', 'wb') as f:f.write(jpg.content) # 写入图片内容
name += 1 # 编号增加 1
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _decode(self, data, decode_content, flush_decoder)
#     480             if self._decoder:
# --> 481                 data = self._decoder.decompress(data)
#     482                 self._has_decoded_content = True
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in decompress(self, data)
#     126             try:
# --> 127                 ret += self._obj.decompress(data)
#     128             except zlib.error:
#
# error: Error -3 while decompressing data: incorrect header check
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import os
from google.colab import drive
# 挂载 Google Drive(可选,如果需要保存到云端硬盘)
drive.mount('/content/drive')
# 定义并创建保存图片的目录
save_dir = '/content/drive/MyDrive/ Notebooks/download/'
if not os.path.exists(save_dir):
  os.makedirs(save_dir)
web = requests.get('https://www.ptt.cc/bbs/Beauty/M.1710593264.A.578.html',
cookies={'over18':'1'})
soup = BeautifulSoup(web.text, "html.parser")
imgs = soup.find_all('img')
name = 0 # 设定图片编号
for i in imgs:
  print(i['src'])
  jpg = requests.get(i['src']) # 使用 requests 获取图片内容
  with open(f'{save_dir}test_{name}.jpg', 'wb') as f:
    f.write(jpg.content) # 写入图片内容
  name += 1 # 编号增加 1
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# https://cache.ptt.cc/c/https/i.imgur.com/zSCKh5fl.jpg?e=1732369864&s=KmjRfK3B_arIFjHokcja1g
# https://cache.ptt.cc/c/https/i.imgur.com/4Xfq2nrl.jpg?e=1732374541&s=EIcX0hS46H0kjswqWvnVcg
# https://cache.ptt.cc/c/https/i.imgur.com/vJIMY03l.jpg?e=1732318836&s=HgNLPDkK1jgoN5umrFwkEw
# https://cache.ptt.cc/c/https/i.imgur.com/wKWzZBfl.jpg?e=1732317043&s=GXppg4TaL4-TvNtsXQInSg
# https://cache.ptt.cc/c/https/i.imgur.com/5a24s64l.jpg?e=1732332807&s=-lS9175ldxcWjB2Wtkx5Bg
# https://cache.ptt.cc/c/https/i.imgur.com/3bPuFPyl.jpg?e=1732357271&s=jiFDOjw3ZgyfYvwo7kiPBw
# https://cache.ptt.cc/c/https/i.imgur.com/FfVPpXyl.jpg?e=1732331817&s=WQQv0A8Gp-a6pCdQzZ5eSQ
# https://cache.ptt.cc/c/https/i.imgur.com/jGCMjBil.jpg?e=1732371362&s=NkRn4o0108IJam7KfyK_lg
# https://cache.ptt.cc/c/https/i.imgur.com/jDLMlT9l.jpg?e=1732358656&s=_Sj8dIWJ7hM__skUklJqhQ
# ...

# %%
import requests
url = 'https://invoice.etax.nat.gov.tw/index.html'
web = requests.get(url) # 取得網頁內容
web.encoding='utf-8' # 因為該網頁編碼為 utf-8,加上 .encoding避免亂碼
print(web.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head>
#
#     <!-- Google Analytics -->
#     <!-- Google tag (gtag.js) -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=G-1RL7V80ELX"></script>
#     <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-1RL7V80ELX');
#     </script>
#
#   <meta charset="UTF-8" />
#   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#   <meta name="format-detection" content="telephone=no" />
#   <meta name="viewport" content="width=device-width,initial-scale=1, user-scalable=no" />
#   <title>財政部稅務入口網</title>
#   <link rel="shortcut icon" type="image/x-icon" href="images/favicon.ico">
#   <!-- CSS_JS -->
#   <link rel="stylesheet" href="css/bootstrap.css">
#   <!-- CSS -->
#   <link rel="stylesheet" href="css/global.css">
#   <link rel="stylesheet" href="css/inner.css">
#   <!-- JS -->
# ...

# %%
import requests
url = 'https://invoice.etax.nat.gov.tw/index.html'
web = requests.get(url) # 取得網頁內容
web.encoding='utf-8' # 因為該網頁編碼為 utf-8,加上 .encoding 避免亂碼
from bs4 import BeautifulSoup
soup = BeautifulSoup(web.text, "html.parser") # 轉換成標籤樹
td = soup.select('.container-fluid')[0].select('.etw-tbiggest') #取出中獎號碼的位置
ns = td[0].getText() # 特別獎
n1 = td[1].getText() # 特獎
# 頭獎,因為存入串列會出現 /n 換行符,使用 [-8:] 取出最後八碼
n2 = [td[2].getText()[-8:], td[3].getText()[-8:], td[4].getText()[-8:]]
print(ns)
print(n1)
print(n2)
# Out:
# 38039158
# 08276859
# ['32110911', '84289408', '13446901']

# %%
import requests
url = 'https://rate.bot.com.tw/xrt/flcsv/0/day' # 牌告匯率 CSV 網址
rate = requests.get(url) # 爬取網址內容
rate.encoding = 'utf-8' # 調整回應訊息編碼為 utf-8,避免編碼不同造成亂碼
rt = rate.text # 以文字模式讀取內容
rts = rt.split('\n') # 使用「換行」將內容拆分成串列
for i in rts: # 讀取串列的每個項目
  try: # 使用 try 避開最後一行的空白行
    a = i.split(',') # 每個項目用逗號拆分成子串列
    print(a[0] + ': ' + a[12]) # 取出第一個 ( 0 ) 和第十三個項目 ( 12 )
  except:break
# Out:
# ﻿幣別: 現金
# USD: 32.81500
# HKD: 4.23000
# GBP: 42.03000
# AUD: 21.58000
# CAD: 23.71000
# SGD: 24.56000
# CHF: 37.24000
# JPY: 0.21470
# ZAR: 0.00000
# SEK: 0.00000
# NZD: 19.45000
# THB: 1.00190
# PHP: 0.61740
# IDR: 0.00238
# EUR: 34.78000
# KRW: 0.02540
# VND: 0.00145
# MYR: 7.79100
# CNY: 4.55900

# %% [markdown]
# ### The Silent Web
#
# In a small, quiet town nestled between rolling hills, there was a curious young girl named Emma. She had a love for technology, often spending hours learning about the mysterious world of coding. While other children played outside or read books, Emma sat by her computer, her fingers dancing across the keyboard, weaving lines of code into something magical.
#
# One day, while rummaging through an online forum, Emma discovered a cryptic message. It was a post from an anonymous user, claiming they had unlocked the secret to communicating with the "Silent Web." This web, they wrote, was different from the usual internet most people knew. It was a hidden network, one that only those with the right skills could access. Intrigued by the idea of a hidden world waiting to be discovered, Emma decided to investigate.
#
# She started her quest by searching for the clues mentioned in the post, piecing together fragments of information like a puzzle. Her first challenge came when she stumbled upon a strange file—a CSV file that contained long strings of numbers and symbols. The user had left a small hint: "Decode the language, and you will hear the whispers."
#
# Determined, Emma opened the file and, using her knowledge of programming, began to process the data. She knew that the numbers and symbols could represent something more. As she wrote her script, the screen flickered with each line of code she typed. The file, once a jumble of characters, began to reveal patterns.
#
# Hours passed, but Emma didn’t mind. She was deep into her work, determined to crack the code. Finally, her program ran successfully, extracting meaningful data from the CSV. The output was strange but beautiful—currency exchange rates from every corner of the world. It wasn’t much, but it was a start.
#
# Suddenly, the computer screen went dark. Emma stared at it, puzzled. Then, a new message appeared, typed out slowly on the screen:
#
# *“You’ve unlocked the first door, Emma. But the journey has just begun. The Silent Web is waiting.”*
#
# With a sense of awe and excitement, Emma leaned forward, her heart racing. She had done it. She had found the first clue to something much larger, something hidden beneath the surface of the world she thought she knew.
#
# From that day on, Emma continued her journey, learning new languages of code, solving puzzles, and uncovering more secrets. Every discovery led her closer to understanding the Silent Web. And with each discovery, Emma felt a sense of connection to something far beyond the reach of ordinary users—a web of hidden knowledge, waiting to be explored by those brave enough to search for it.
#
# But Emma knew that, like any great adventure, this one was full of mysteries yet to be solved. She smiled, her fingers already poised over the keyboard, ready for whatever came next.
#
# ---
#
# In this story, Emma's journey into the world of hidden code mirrors the experience of uncovering secrets hidden in plain sight. Like the code you wrote, sometimes it takes persistence, curiosity, and a willingness to dig deeper to find the magic that lies beneath.

# %%
import requests

url = 'https://www.cbc.gov.tw/dl.aspx?uid=2329&pid=1978'  # 示例URL，請替換為有效的CSV檔案URL
rate = requests.get(url)

# 檢查回應的HTTP狀態碼
# print(f"HTTP Status Code: {rate.status_code}")

# 設定編碼為UTF-8
rate.encoding = 'utf-8'

# 讀取CSV內容
rt = rate.text
rts = rt.split('\n')

# 處理每一行並輸出特定欄位
for i in rts:
    if not i.strip():  # 忽略空白行
        continue
    try:
        a = i.split(',')
        print(a[0] + ': ' + a[12])  # 打印第一列和第十三列
    except IndexError:
        continue  # 當行列數不足13時跳過
    except Exception as e:
        print(f"Error: {e}")
        break
# Out:
# 							[31.926: 31.840
# 							[499.60: 544.90
# 							[6.69: 8.44
# 							[0.822: 0.824
# 							['2024/09/06': '2024/09/25'
# 							['2020.09': '2021.09'
# 							['2020.08': '2021.08'
# 							['2024/09/06': '2024/09/25'
