# %%
def hello():
  print('hello')
hello()
# Out:
# hello

# %%
def hello(msg):
  print(msg)
hello('hide')
hello('good morning')
# Out:
# hide
# good morning

# %%
def hello(x,y=10):
  z = x + y
  print(z)
hello(x=6,y=10)
# Out:
# 16

# %%
def hello(name,age):
  msg=f'{name} is {age} years old'
  print(msg)
hello(name = 'wlk',age = '16')
# Out:
# wlk is 16 years old

# %%
def a(x,y):
  result = x + y * 2
  return result

b = a (1,2)
c = a (2,3)
(b,c)
# Out:
# (5, 8)

# %%
def a (x):
  result = 0
  while result < 10:
    result = result + x
    if result ==5:
      return result
  return result
b = a (1)
c = a (2)
(b,c)
# Out:
# (5, 10)

# %%
def tf(value):
  return 2*value -1

test_values = [0.0,0.0011, 0.25, 0.5, 0.54, 0.75, 1.0]
scaled_values = [tf(value)for value in test_values]
print ("Original values:",test_values)
print ("Scaled values:",scaled_values)
# Out:
# Original values: [0.0, 0.0011, 0.25, 0.5, 0.54, 0.75, 1.0]
# Scaled values: [-1.0, -0.9978, -0.5, 0.0, 0.08000000000000007, 0.5, 1.0]

# %%
def a (n):
  if n== 0 or n == 1:
    return 1
  else:
      return n + a (n-1)

print(a(3))
print(a(5))
# Out:
# 6
# 15

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
with open('test.txt','w')as f1 :
  f1.write ('good morning')

# %%
import datetime
print(datetime.datetime.now())
print(datetime.date.today())
# Out:
# 2024-09-26 08:57:51.712738
# 2024-09-26

# %%
import datetime as dd
print(dd.datetime.now())
print(dd.date.today())
# Out:
# 2024-09-26 08:59:47.832036
# 2024-09-26

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# 下面是在教creating dataFarme 先要给pd date()然后给日期和oeriod 数 然后list 出来

# %%
dates = pd.date_range("20130101",periods=6)
dates

df = pd.DataFrame(np.random.randn(6,4),index = dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.341782 -0.667528 -0.944828  0.149742
# 2013-01-02 -0.116837 -2.221111  1.091420 -1.146641
# 2013-01-03 -0.083637 -1.227503 -0.178651 -0.433273
# 2013-01-04  0.637131 -0.966035  0.606209 -1.475150
# 2013-01-05 -0.028092 -0.837159  1.090864 -0.773983
# 2013-01-06 -0.171181  0.597769 -1.969263 -0.987217

# %% [markdown]
# 用df 和 df.tail 查看框架的顶部和底部

# %%
df.head()
df.tail(3)
df.index
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# 返回使用df.to_numpy ,用numpy表示就不用索引或列标签

# %%
df2 = df.copy()
df2.to_numpy()
# Out:
# array([[-0.34178156, -0.66752845, -0.94482845,  0.14974239],
#        [-0.11683716, -2.22111074,  1.09142037, -1.14664094],
#        [-0.08363688, -1.22750284, -0.17865058, -0.43327313],
#        [ 0.6371314 , -0.96603466,  0.60620922, -1.47514995],
#        [-0.02809204, -0.83715944,  1.0908642 , -0.77398292],
#        [-0.17118087,  0.59776893, -1.96926333, -0.98721718]])

# %% [markdown]
# 了解这个资料从哪里来和他的形态

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.017400 -0.886928 -0.050708 -0.777754
# std    0.338134  0.911837  1.227669  0.573628
# min   -0.341782 -2.221111 -1.969263 -1.475150
# 25%   -0.157595 -1.162136 -0.753284 -1.106785
# 50%   -0.100237 -0.901597  0.213779 -0.880600
# 75%   -0.041978 -0.709936  0.969700 -0.518451
# max    0.637131  0.597769  1.091420  0.149742

# %% [markdown]
# 转换数据

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.341782   -0.116837   -0.083637    0.637131   -0.028092   -0.171181
# B   -0.667528   -2.221111   -1.227503   -0.966035   -0.837159    0.597769
# C   -0.944828    1.091420   -0.178651    0.606209    1.090864   -1.969263
# D    0.149742   -1.146641   -0.433273   -1.475150   -0.773983   -0.987217

# %%
df3 = dfCopy()
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.341782   -0.116837   -0.083637    0.637131   -0.028092   -0.171181
# B   -0.667528   -2.221111   -1.227503   -0.966035   -0.837159    0.597769
# C   -0.944828    1.091420   -0.178651    0.606209    1.090864   -1.969263
# D    0.149742   -1.146641   -0.433273   -1.475150   -0.773983   -0.987217

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.149742 -0.944828 -0.667528 -0.341782
# 2013-01-02 -1.146641  1.091420 -2.221111 -0.116837
# 2013-01-03 -0.433273 -0.178651 -1.227503 -0.083637
# 2013-01-04 -1.475150  0.606209 -0.966035  0.637131
# 2013-01-05 -0.773983  1.090864 -0.837159 -0.028092
# 2013-01-06 -0.987217 -1.969263  0.597769 -0.171181

# %% [markdown]
# 用df[][]并列写需要的column和list

# %%
df["A"][0:3]
# Out:
# 2013-01-01   -0.341782
# 2013-01-02   -0.116837
# 2013-01-03   -0.083637
# Freq: D, Name: A, dtype: float64

# %%
df.loc[dates[0]]
df.loc[:,["A","B"]]
df.loc["20130102":"20130104",["A","B"]]
df.loc[dates[0],"A"]
# Out:
# -0.3417815553529436

# %% [markdown]
# 用iloc找想要知道的排列

# %%
df.iloc[3]
df.iloc[3:5,0:2]
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.116837 -2.221111  1.091420 -1.146641
# 2013-01-03 -0.083637 -1.227503 -0.178651 -0.433273

# %% [markdown]
# 利用条件找自己想要的资料

# %%
df[df>0]
df[df["A"]>0]
# Out:
#                    A         B         C        D
# 2013-01-04  0.637131 -0.966035  0.606209 -1.47515

# %%
df2 = df.copy()
df2["E"]=["one","one","two","three","four","three"]
df2[df2["E"].isin(["two","four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.083637 -1.227503 -0.178651 -0.433273   two
# 2013-01-05 -0.028092 -0.837159  1.090864 -0.773983  four

# %%
df2 = df.copy()
df2[df2>0] =-df2
df2
# Out:
#                    A         B         C         D
# 2013-01-01 -0.341782 -0.667528 -0.944828 -0.149742
# 2013-01-02 -0.116837 -2.221111 -1.091420 -1.146641
# 2013-01-03 -0.083637 -1.227503 -0.178651 -0.433273
# 2013-01-04 -0.637131 -0.966035 -0.606209 -1.475150
# 2013-01-05 -0.028092 -0.837159 -1.090864 -0.773983
# 2013-01-06 -0.171181 -0.597769 -1.969263 -0.987217

# %%
df1 = df.reindex(index=dates[0:4],columns=list(df.columns)+["E"])
df1.loc[dates[0]:dates[1],"E"]=1
df1
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.341782 -0.667528 -0.944828  0.149742  1.0
# 2013-01-02 -0.116837 -2.221111  1.091420 -1.146641  1.0
# 2013-01-03 -0.083637 -1.227503 -0.178651 -0.433273  NaN
# 2013-01-04  0.637131 -0.966035  0.606209 -1.475150  NaN

# %%
df1.dropna()
df1.fillna(5)
df1.interpolate()
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.341782 -0.667528 -0.944828  0.149742  1.0
# 2013-01-02 -0.116837 -2.221111  1.091420 -1.146641  1.0
# 2013-01-03 -0.083637 -1.227503 -0.178651 -0.433273  1.0
# 2013-01-04  0.637131 -0.966035  0.606209 -1.475150  1.0

# %%
df.mean()
df.std()
df.mean(axis=1)
df.std(axis=1)
# Out:
# 2013-01-01    0.470309
# 2013-01-02    1.416704
# 2013-01-03    0.519248
# 2013-01-04    1.083822
# 2013-01-05    0.897307
# 2013-01-06    1.101384
# Freq: D, dtype: float64
